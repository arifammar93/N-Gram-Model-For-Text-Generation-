# %% [markdown]
# # N-Gram Shakesperean Text Generator with Smoothing
#
# **Overview:**
# This is a simple project to develop a n-grame text generation model (with smoothing). The goal is to use a corpus consisting of Shakespeare's plays to generate text in Shakesperian style. Furthermore, perplexity of a text is rated with the given model.

# %%
#Getting the corpus from repo
# !wget -O corpus.zip https://digitalrepository.wheatoncollege.edu/bitstream/handle/11040/24451/Shakespeare%20Corpus%20by%20Play.zip?sequence=1&isAllowed=y
# Out:
# --2022-05-12 10:32:39--  https://digitalrepository.wheatoncollege.edu/bitstream/handle/11040/24451/Shakespeare%20Corpus%20by%20Play.zip?sequence=1
# Resolving digitalrepository.wheatoncollege.edu (digitalrepository.wheatoncollege.edu)... 52.45.246.5
# Connecting to digitalrepository.wheatoncollege.edu (digitalrepository.wheatoncollege.edu)|52.45.246.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8536913 (8.1M) [application/octet-stream]
# Saving to: ‘corpus.zip’
#
# corpus.zip          100%[===================>]   8.14M  42.8MB/s    in 0.2s
#
# 2022-05-12 10:32:40 (42.8 MB/s) - ‘corpus.zip’ saved [8536913/8536913]

# %% [markdown]
# Now, we will unzip the corpus

# %%
# !unzip corpus.zip
# Out:
# Archive:  corpus.zip
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII_SCRBnoCN_noSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/_DS_Store
#   inflating: Shakespeare Corpus by Play/macbeth/_DS_Store
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/_DS_Store
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth_SCRBnoCNnoSD_S.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/_DS_Store
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryV/_DS_Store
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/_DS_Store
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryV/henryV_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/muchAdoAboutNothing/_DS_Store
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/_DS_Store
#   inflating: Shakespeare Corpus by Play/muchAdoAboutNothing/muchAdoAboutNothing_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/hamlet/_DS_Store
#   inflating: Shakespeare Corpus by Play/muchAdoAboutNothing/muchAdoAboutNothing_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/_DS_Store
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/_DS_Store
#   inflating: Shakespeare Corpus by Play/kingJohn/_DS_Store
#   inflating: Shakespeare Corpus by Play/hamlet/hamlet_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/hamlet/hamlet_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVSceneviii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/_DS_Store
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/_DS_Store
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/_DS_Store
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/_DS_Store
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActIV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActIV_SCRBnoCNnoSD (1).txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActIII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActV_SCRBnoCNnoSD (1).txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActI_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti_Acts/henryIVpartiActII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar_Acts/juliusCaesarActI_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline_Acts/cymbelineActI_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIIPrologue_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar_Acts/juliusCaesarActIII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_Acts/edwardIIIActII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/_DS_Store
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_Acts/edwardIIIActIV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIVScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_Acts/edwardIIIActV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/_DS_Store
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_Acts/edwardIIIActIII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/MidsummerNightsDream_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_Acts/henryIVpartiiActIII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIIScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIPrologue_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/_DS_Store
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /_DS_Store
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIPrologue_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIVScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIISceneiii_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActVPrologue_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline_Acts/cymbelineActIII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVScenevii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_Acts/asYouLikeItActII_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_Acts/asYouLikeItActI_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_Acts/asYouLikeItActIII_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIVScenex_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIIIScenevii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActIIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIIIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure_Acts/measureForMeasureActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost/lovesLaboursLostActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIIIScenevii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIVPrologue_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_Acts/allsWellThatEndsWellActV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/muchAdoAboutNothing/muchAdoAboutNothing_Acts/muchAdoAboutNothingActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/pericles/_DS_Store
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_Acts/henryIVpartiiActV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost/lovesLaboursLostActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIIIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline_Acts/cymbelineActIV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_Acts/allsWellThatEndsWellActIII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActIISceneviii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/pericles/pericles_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_Acts/edwardIIIActI_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost/lovesLaboursLostActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIISceneii_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIIIScenei_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar_Acts/juliusCaesarActIV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActIISceneix_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/_DS_Store
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_Acts/allsWellThatEndsWellActI_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActISceneviii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii_Acts/henryVIpartiiActI_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen_Acts/twoNobleKinsmenActI_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii_Acts/henryVIpartiiActIII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /antonyAndCleopatraActIIIScenex_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIVScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_Acts/asYouLikeItActIV_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream/midsummerNightsDreamActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost/lovesLaboursLostActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure_Acts/measureForMeasureActII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/_DS_Store
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream_Acts/aMidsummerNightsDreamActIII_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/wintersTale/wintersTale_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/_DS_Store(1)
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIVSceneviii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_Acts/henryIVpartiiActI_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIISceneiv_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/kingLear/_DS_Store
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /antonyAndCleopatraActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_Acts/henryIVpartiiActII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIVSceneviii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIVScenevii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear_Acts/kingLearActII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIVSceneix_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream_Acts/aMidsummerNightsDreamActII_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar/juliusCaesarActVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/muchAdoAboutNothing/muchAdoAboutNothing_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/richardII/richardII_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream_Acts/aMidsummerNightsDreamActI_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure/measureForMeasureActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/titusAndronicus/titusAndronicus/_DS_Store
#   inflating: Shakespeare Corpus by Play/muchAdoAboutNothing/muchAdoAboutNothing_Acts/muchAdoAboutNothingActIV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream/midsummerNightsDreamActIIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIISceneiii_noCN.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii/henryVIpartiiActIVSceneix_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/troilusAndCressida/troilusAndCressida_Acts/troilusAndCressidaActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_Acts/asYouLikeItActV_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/pericles/pericles_Acts/periclesActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /_DS_Store
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost_Acts/lovesLaboursLostActI_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost_Acts/lovesLaboursLostActII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen_Acts/twoNobleKinsmenActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/pericles/pericles_Acts/periclesActIII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/_DS_Store
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen/twoNobleKinsmenActIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/titusAndronicus/titusAndronicus_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/measureForMeasure/measureForMeasure/measureForMeasureActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /_DS_Store
#   inflating: Shakespeare Corpus by Play/richardII/richardII_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIII/henryVIII/henryVIIIActIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActIVScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar/juliusCaesarActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/wintersTale/wintersTale/_DS_Store
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingLear/kingLear/kingLearActIVScenevii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn_Acts/kingJohnActII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/richardII/richardII_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /antonyAndCleopatraActIVScenexiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus_Acts/coriolanusActIII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIScenex_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii/henryVIpartiiiActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/wintersTale/wintersTale_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost_Acts/lovesLaboursLostActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /antonyAndCleopatraActIIIScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActVSceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /antonyAndCleopatraActIVScenevi_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/cymbeline/cymbeline /cymbelineActIScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /antonyAndCleopatraActIIISceneix_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth/macbethActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/troilusAndCressida/troilusAndCressida_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartii/henryVIpartii_SCRBnoCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/wintersTale/wintersTale_Acts/theWintersTaleActII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/coriolanus/coriolanus/coriolanusActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActIIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream/midsummerNightsDreamActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen_Acts/twoNobleKinsmenActIII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/macbeth/macbeth_Acts/macbethActII_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/wintersTale/wintersTale/wintersTaleActVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell /allsWellThatEndsWellActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/kingJohn/kingJohn/kingJohnActVScenevii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice/merchantOfVeniceActISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar/juliusCaesarActIISceneiv_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen/twoNobleKinsmenActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream/midsummerNightsDreamActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/juliusCaesar/juliusCaesar/_DS_Store
#   inflating: Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors/comedyOfErrorsActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIVPrologue_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII_Acts/_DS_Store
#   inflating: Shakespeare Corpus by Play/edwardIII/edwardIII /edwardIIIActIIISceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/wintersTale/wintersTale/wintersTaleActVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor_Acts/theMerryWivesOfWindsorActV_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost/lovesLaboursLostActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/pericles/pericles/periclesActVscenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActIVSceneii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt /asYouLikeItActIIScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsW
enei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii_Acts/henryVIpartiiiActI_SCRBnoCnnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryIVparti/henryIVparti/henryIVpartiActVScenev_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra /_DS_Store
#   inflating: Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_Acts/henryIVpartiiActIV_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/tamingOfTheShrew/_DS_Store
#   inflating: Shakespeare Corpus by Play/henryV/henryV/henryVActIISceneiv_noCNnoSD(1).txt
#   inflating: Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor/merryWivesOfWindsorActIIISceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost/lovesLaboursLostActIVScenei_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/henryVIparti/henryVIparti_noSCRB.txt
#   inflating: Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_Acts/allsWellThatEndsWellActII_SCRBnoCNnoSD .txt
#   inflating: Shakespeare Corpus by Play/tamingOfTheShrew/tamingOfTheShrew/tamingOfTheShrewActIVSceneiii_noCNnoSD.txt
#   inflating: Shakespeare Corpus by Play/tempest/tempest/tempestActVScenei_noCNnoSD.txt

# %% [markdown]
# We can even have python and the command line interact.

# %%
files = !ls Shake*/*/*_noSCRB.txt

# %% [markdown]
# `files` is now a list containing all of the files we wish to use in our data

# %%
print(files)
# Out:
# ["'Shakespeare Corpus by Play/allsWellThatEndsWell/allsWellThatEndsWell_noSCRB.txt'", "'Shakespeare Corpus by Play/antonyAndCleopatra/antonyAndCleopatra_noSCRB.txt'", "'Shakespeare Corpus by Play/asYouLikeIt/asYouLikeIt_noSCRB.txt'", "'Shakespeare Corpus by Play/comedyOfErrors/comedyOfErrors_noSCRB.txt'", "'Shakespeare Corpus by Play/coriolanus/coriolanus_noSCRB.txt'", "'Shakespeare Corpus by Play/cymbeline/cymbeline_noSCRB.txt'", "'Shakespeare Corpus by Play/edwardIII/edwardIII_noSCRB.txt'", "'Shakespeare Corpus by Play/hamlet/hamlet_noSCRB.txt'", "'Shakespeare Corpus by Play/henryIVparti/henryIVparti_noSCRB.txt'", "'Shakespeare Corpus by Play/henryIVpartii/henryIVpartii_noSCRB.txt'", "'Shakespeare Corpus by Play/henryV/henryV_noSCRB.txt'", "'Shakespeare Corpus by Play/henryVIII/henryVIII_noSCRB.txt'", "'Shakespeare Corpus by Play/henryVIparti/henryVIparti_noSCRB.txt'", "'Shakespeare Corpus by Play/henryVIpartii/henryVIpartii_noSCRB.txt'", "'Shakespeare Corpus by Play/henryVIpartiii/henryVIpartiii_noSCRB.txt'", "'Shakespeare Corpus by Play/juliusCaesar/juliusCaesar_noSCRB.txt'", "'Shakespeare Corpus by Play/kingJohn/kingJohn_noSCRB.txt'", "'Shakespeare Corpus by Play/kingLear/kingLear_noSCRB.txt'", "'Shakespeare Corpus by Play/lovesLaboursLost/lovesLaboursLost_noSCRB.txt'", "'Shakespeare Corpus by Play/macbeth/macbeth_noSCRB.txt'", "'Shakespeare Corpus by Play/measureForMeasure/measureForMeasure_noSCRB.txt'", "'Shakespeare Corpus by Play/merchantOfVenice/merchantOfVenice_noSCRB.txt'", "'Shakespeare Corpus by Play/merryWivesOfWindsor/merryWivesOfWindsor_noSCRB.txt'", "'Shakespeare Corpus by Play/midsummerNightsDream/midsummerNightsDream_noSCRB.txt'", "'Shakespeare Corpus by Play/muchAdoAboutNothing/muchAdoAboutNothing_noSCRB.txt'", "'Shakespeare Corpus by Play/othello/othello_noSCRB.txt'", "'Shakespeare Corpus by Play/pericles/pericles_noSCRB.txt'", "'Shakespeare Corpus by Play/richardIII/richardIII_noSCRB.txt'", "'Shakespeare Corpus by Play/richardII/richardII_noSCRB.txt'", "'Shakespeare Corpus by Play/romeoAndJuliet/romeoAndJuliet_noSCRB.txt'", "'Shakespeare Corpus by Play/tamingOfTheShrew/tamingOfTheShrew_noSCRB.txt'", "'Shakespeare Corpus by Play/tempest/tempest_noSCRB.txt'", "'Shakespeare Corpus by Play/timonOfAthens/timonOfAthens_noSCRB.txt'", "'Shakespeare Corpus by Play/titusAndronicus/titusAndronicus_noSCRB.txt'", "'Shakespeare Corpus by Play/troilusAndCressida/troilusAndCressida_noSCRB.txt'", "'Shakespeare Corpus by Play/twelfthNight/twelfthNight_noSCRB.txt'", "'Shakespeare Corpus by Play/twoGentlemenOfVerona/twoGentlemenOfVerona_noSCRB.txt'", "'Shakespeare Corpus by Play/twoNobleKinsmen/twoNobleKinsmen_noSCRB.txt'", "'Shakespeare Corpus by Play/wintersTale/wintersTale_noSCRB.txt'"]

# %% [markdown]
# Note, there are extra quotes on the files, so we will use list comprehension to remove those

# %%
files = [file[1:-1] for file in files]

# %% [markdown]
# #STEP 1
#
#
# * Go through all of the files
#   * Load the file `file = open(filename,'r')`
#   * Use the spacy tokenizer to tokenize the text `tokens = tokenizer(file.read())`
#   * Loop through the tokens and make everything lowercase `.lower()`
#   * Use all of this to make a list (for each file) of lists of strings (the tokens in each file) called `texts`
#
#
#
#   e.g.
#
#   If we read in one file that looked like:
#
#     HAMLET: Alas poor Yorick.
#
#     GRAVEDIGGER: Put that skull down.
#
#
#
#   The end results should look like:
#
#   `texts = [['<s>', 'HAMLET:', 'Alas', 'poor', 'Yorick.','\n','GRAVEDIGGER:', Put','that', 'skull', 'down.', '</s>']]`

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (4.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)

# %%
from spacy.lang.en import English
nlp = English()

# Create a Tokenizer with the default settings for English
# including punctuation rules and exceptions
tokenizer = nlp.tokenizer
texts = []

# Looping through files and tokenizing
for num, filename in enumerate(files):
  file = open(filename,'r')
  tokens = tokenizer(file.read())
  texts.append([])
  for token in tokens:
    token = token.text.lower()
    texts[num].append(token)

# %%
print(texts[0:2])
# Out:
# [['1603', '\n\n', 'alls', 'well', 'that', 'ends', 'well', '\n\n', 'by', 'william', 'shakespeare', '\n\n\n', 'dramatis', 'personae', '\n\n  ', 'king', 'of', 'france', '\n  ', 'the', 'duke', 'of', 'florence', '\n  ', 'bertram', ',', 'count', 'of', 'rousillon', '\n  ', 'lafeu', ',', 'an', 'old', 'lord', '\n  ', 'parolles', ',', 'a', 'follower', 'of', 'bertram', '\n  ', 'two', 'french', 'lords', ',', 'serving', 'with', 'bertram', '\n\n  ', 'steward', ',', 'servant', 'to', 'the', 'countess', 'of', 'rousillon', '\n  ', 'lavache', ',', 'a', 'clown', 'and', 'servant', 'to', 'the', 'countess', 'of', 'rousillon', '\n  ', 'a', 'page', ',', 'servant', 'to', 'the', 'countess', 'of', 'rousillon', '\n\n  ', 'countess', 'of', 'rousillon', ',', 'mother', 'to', 'bertram', '\n  ', 'helena', ',', 'a', 'gentlewoman', 'protected', 'by', 'the', 'countess', '\n  ', 'a', 'widow', 'of', 'florence', '.', '\n  ', 'diana', ',', 'daughter', 'to', 'the', 'widow', '\n\n\n  ', 'violenta', ',', 'neighbour', 'and', 'friend', 'to', 'the', 'widow', '\n  ', 'mariana', ',', 'neighbour', 'and', 'friend', 'to', 'the', 'widow', '\n\n  ', 'lords', ',', 'officers', ',', 'soldiers', ',', 'etc', '.', ',', 'french', 'and', 'florentine', '\n\n\n\n\n', 'scene', ':', '\n', 'rousillon', ';', 'paris', ';', 'florence', ';', 'marseilles', '\n\n\n', 'act', 'i.', 'scene', '1', '.', '\n', 'rousillon', '.', 'the', 'count', "'s", 'palace', '\n\n', 'enter', 'bertram', ',', 'the', 'countess', 'of', 'rousillon', ',', 'helena', ',', 'and', 'lafeu', ',', 'all', 'in', 'black', '\n\n  ', 'countess', '.', 'in', 'delivering', 'my', 'son', 'from', 'me', ',', 'i', 'bury', 'a', 'second', 'husband', '.', '\n  ', 'bertram', '.', 'and', 'i', 'in', 'going', ',', 'madam', ',', 'weep', "o'er", 'my', 'father', "'s", 'death', 'anew', ';', '\n    ', 'but', 'i', 'must', 'attend', 'his', 'majesty', "'s", 'command', ',', 'to', 'whom', 'i', 'am', 'now', 'in', '\n    ', 'ward', ',', 'evermore', 'in', 'subjection', '.', '\n  ', 'lafeu', '.', 'you', 'shall', 'find', 'of', 'the', 'king', 'a', 'husband', ',', 'madam', ';', 'you', ',', 'sir', ',', 'a', '\n    ', 'father', '.', 'he', 'that', 'so', 'generally', 'is', 'at', 'all', 'times', 'good', 'must', 'of', '\n    ', 'necessity', 'hold', 'his', 'virtue', 'to', 'you', ',', 'whose', 'worthiness', 'would', 'stir', 'it', '\n    ', 'up', 'where', 'it', 'wanted', ',', 'rather', 'than', 'lack', 'it', 'where', 'there', 'is', 'such', '\n    ', 'abundance', '.', '\n  ', 'countess', '.', 'what', 'hope', 'is', 'there', 'of', 'his', 'majesty', "'s", 'amendment', '?', '\n  ', 'lafeu', '.', 'he', 'hath', "abandon'd", 'his', 'physicians', ',', 'madam', ';', 'under', 'whose', '\n    ', 'practices', 'he', 'hath', 'persecuted', 'time', 'with', 'hope', ',', 'and', 'finds', 'no', 'other', '\n    ', 'advantage', 'in', 'the', 'process', 'but', 'only', 'the', 'losing', 'of', 'hope', 'by', 'time', '.', '\n  ', 'countess', '.', 'this', 'young', 'gentlewoman', 'had', 'a', 'father-', 'o', ',', 'that', "'", 'had', ',', "'", 'how', '\n    ', 'sad', 'a', 'passage', "'", 'tis!-whose', 'skill', 'was', 'almost', 'as', 'great', 'as', 'his', '\n    ', 'honesty', ';', 'had', 'it', "stretch'd", 'so', 'far', ',', 'would', 'have', 'made', 'nature', '\n    ', 'immortal', ',', 'and', 'death', 'should', 'have', 'play', 'for', 'lack', 'of', 'work', '.', 'would', ',', 'for', '\n    ', 'the', 'king', "'s", 'sake', ',', 'he', 'were', 'living', '!', 'i', 'think', 'it', 'would', 'be', 'the', 'death', 'of', '\n    ', 'the', 'king', "'s", 'disease', '.', '\n  ', 'lafeu', '.', 'how', "call'd", 'you', 'the', 'man', 'you', 'speak', 'of', ',', 'madam', '?', '\n  ', 'countess', '.', 'he', 'was', 'famous', ',', 'sir', ',', 'in', 'his', 'profession', ',', 'and', 'it', 'was', 'his', '\n    ', 'great', 'right', 'to', 'be', 'so-', 'gerard', 'de', 'narbon', '.', '\n  ', 'lafeu', '.', 'he', 'was', 'excellent', 'indeed', ',', 'madam', ';', 'the', 'king', 'very', 'lately', 'spoke', '\n    ', 'of', 'him', 'admiringly', 'and', 'm ...

# %% [markdown]
# #STEP 2
#
# With our files read in, it's time to do some counting!
#
# * Implement the function `get_counts(texts,n)` which takes in a list of list of strings -- `texts` -- and the arity of the n-gram -- `n`
# * `get_counts` should return a dictionary where the keys are the n-grams (as tuples of strings) and the values are the integer counts of all of the found n-grams
#
#
# Here's a quick primer on tuples in Python
#
#     triple = (1,2,3)
#     double = (1,2)
#     single = (1,) #note the trailing comma to distinguish from parenethesis
#     null_tuple = tuple()
#
#     list_triple = [1,2,3]
#     tuple_triple = tuple(list_triple)

# %%
def get_counts(texts,n):
  ngrams = {}
  for i in range(len(texts)):
    for j in range(len(texts[i]) - (n-1)):
      ngram_tuple = tuple(texts[i][j:j+n])
      ngrams[ngram_tuple] = ngrams.get(ngram_tuple,0) + 1
  return ngrams

unigrams = get_counts(texts,1)
bigrams = get_counts(texts,2)
trigrams = get_counts(texts,3)

# %%
print(unigrams)
# Out:
# {('1603',): 1, ('\n\n',): 4188, ('alls',): 1, ('well',): 2331, ('that',): 11791, ('ends',): 52, ('by',): 3935, ('william',): 127, ('shakespeare',): 38, ('\n\n\n',): 115, ('dramatis',): 37, ('personae',): 37, ('\n\n  ',): 2143, ('king',): 3376, ('of',): 18313, ('france',): 580, ('\n  ',): 29590, ('the',): 28976, ('duke',): 1163, ('florence',): 25, ('bertram',): 136, (',',): 87483, ('count',): 128, ('rousillon',): 28, ('lafeu',): 118, ('an',): 1941, ('old',): 714, ('lord',): 3225, ('parolles',): 175, ('a',): 15752, ('follower',): 14, ('two',): 779, ('french',): 256, ('lords',): 501, ('serving',): 28, ('with',): 8147, ('steward',): 47, ('servant',): 453, ('to',): 20682, ('countess',): 179, ('lavache',): 2, ('clown',): 350, ('and',): 27494, ('page',): 437, ('mother',): 453, ('helena',): 194, ('gentlewoman',): 69, ('protected',): 3, ('widow',): 120, ('.',): 80716, ('diana',): 86, ('daughter',): 565, ('\n\n\n  ',): 1, ('violenta',): 2, ('neighbour',): 55, ('friend',): 485, ('mariana',): 48, ('officers',): 88, ('soldiers',): 232, ('etc',): 19, ('florentine',): 13, ('\n\n\n\n\n',): 534, ('scene',): 842, (':',): 2520, ('\n',): 8829, (';',): 18254, ('paris',): 139, ('marseilles',): 5, ('act',): 379, ('i.',): 305, ('1',): 127, ("'s",): 7930, ('palace',): 170, ('enter',): 2548, ('all',): 4114, ('in',): 11412, ('black',): 167, ('delivering',): 4, ('my',): 12891, ('son',): 735, ('from',): 2740, ('me',): 8029, ('i',): 23194, ('bury',):
#   * Implement `score_text` which when given a text (a list of strings) returns the perplexity of that text

# %%
import random
import numpy as np
random.seed(0)

class NGramLM():
  ngram_orders=[]
  n=-1

  def __init__(self,texts,n):
    self.n = n
    m=n
    if m==0:
      self.ngram_orders.reverse()
      return
    ngram_lms = []
    ngram_pr = {}  
    ngram_counts = get_counts(texts,m)
    ngram_less_counts = get_counts(texts,m-1)
      
    for ngram in ngram_counts:
      context = ngram[:-1]
      prediction = ngram[-1]
      probablity = ngram_counts[ngram] / ngram_less_counts[context]
      if context not in ngram_pr:
        ngram_pr[context] = {}
      ngram_pr[context][prediction] = probablity

    self.ngram_orders.append(ngram_pr)
    m = m-1
    self.__init__(texts,m)

  def generate_text(self, length, prompt=[]):
    prompt = [word.lower() for word in prompt]

    for i in range (length):
      r = random.random()
      for j in reversed(range(len(self.ngram_orders))):
        key = tuple(prompt[-(j):])
        if j < 1:
          key = ()
        for context in self.ngram_orders:
          if key in self.ngram_orders[j]:
            for word in self.ngram_orders[j][key]:
              if r<self.ngram_orders[j][key][word] :
                prompt.append(word)
                break
              else:
                r -= self.ngram_orders[j][key][word]
            else:
              continue
            break
        else:
          continue
        break              
            
    return prompt

  def score_text(self,text):
    log_prob = 0
    length = len(text)
    prompt = text
    for i in range (length):
      for j in reversed(range(len(self.ngram_orders))):
        print('ORDER',j)
        key = tuple(prompt[-(j):])
        if j < 1:
          key = ()
        found_probability = False
        if key in self.ngram_orders[j]:
          '''
          if word in self.ngram_orders[j][key]:
            np.log(self.ngram_orders[j][key][word])
          else:
            return float('inf')
          '''
          for word in self.ngram_orders[j][key]:
            if word == prompt[i]:
              log_prob += np.log(self.ngram_orders[j][key][word])
              found_probability = True
              break
          else:
            continue
        if not found_probability:
          return float('inf')

        break
    log_prob /= length   
    return 2**(-log_prob)

# %%
Object1 = NGramLM(texts,3)

# %%
for context in Object1.ngram_orders[0]:
  print(Object1.ngram_orders[0])
# Out:
# {(): {'1603': 7.713216442109225e-07, '\n\n': 0.0032302950459553435, 'alls': 7.713216442109225e-07, 'well': 0.0017979507526556604, 'that': 0.009094653506890987, 'ends': 4.010872549896797e-05, 'by': 0.00303515066996998, 'william': 9.795784881478716e-05, 'shakespeare': 2.9310222480015055e-05, '\n\n\n': 8.87019890842561e-05, 'dramatis': 2.8538900835804135e-05, 'personae': 2.8538900835804135e-05, '\n\n  ': 0.001652942283544007, 'king': 0.0026039818708560743, 'of': 0.014125213270434624, 'france': 0.0004473665536423351, '\n  ': 0.022823407452201197, 'the': 0.02234981596265569, 'duke': 0.0008970470722173029, 'florence': 1.9283041105273063e-05, 'bertram': 0.00010489974361268547, ',': 0.06747753140050414, 'count': 9.872917045899808e-05, 'rousillon': 2.1597006037905832e-05, 'lafeu': 9.101595401688885e-05, 'an': 0.0014971353114134006, 'old': 0.0005507236539665987, 'lord': 0.002487512302580225, 'parolles': 0.00013498128773691145, 'a': 0.012149858539610451, 'follower': 1.0798503018952916e-05, 'two': 0.0006008595608403087, 'french': 0.00019745834091799616, 'lords': 0.0003864321437496722, 'serving': 2.1597006037
#      the very minute bids thee call beatrice to you , and there stand lords . good old abraham ! lords appellants ,
#      though in her chamber ,
#      before not dreamt of unhappiness
#      and sir andrew ; scout me for a looking - glass , pomander , brooch ,
#      lean , old siward ,

# %%
Object1.score_text(['alls', 'well', 'that'])
# Out:
# ORDER 2
# ORDER 1
# ORDER 0
# ORDER 2
# ORDER 1
# ORDER 2
# ORDER 1
# 573.7221461648552

# %%
#We test the model with 3-gram to see different generation based on 1-gram to 3-gram models
for n in [1,2,3]:
  print(f'Order {n} LM:')
  lm = NGramLM(texts,n)

  print(' '.join(lm.generate_text(100)))
  print(' '.join(lm.generate_text(100,['palm', 'to'])))

  print(lm.score_text(['IBM','announced','today','that','they','will','be','buying','Google']))
  print(lm.score_text(['palm', 'to', 'palm', 'is', 'holy', 'palmers']))
  print(lm.score_text(['what','do','you','say','to','that','Hamlet']))
# Out:
# Order 1 LM:
# blood begins . did , . gait from known , ,
#
#    not
#           should know of none your not
#
#      lucio
#    king tearsheet to , and office order'd of his , . . on i to only
#    , fisherman and i did drive antipholus with our diffus'd
#    here gods i . are shall servant it
#      could this all i deserves . very that honour me
#
#  . rue i ; husband habitation love we them
#      but [
#
#  and from . life
#      pleaseth if but
#      once but away
#
# palm to sir . a great what him even trouble ? all good mouth instantly says to florizel love , say roderigo
#      yet in . friends
#
#  double have , , thoughts mirth
#  ben ,
#
#      the . so boy grass , was [ i do't :
#
#
#    know speak armado stomachs shun
#    hear first make dear lictors will
#      for and fair that an from ii       me we
#    a shylock ;
#      ! ; up .
#    to as the
#      my but , leathern it peace plain- i where city whom 's denied
# ORDER 3
# inf
# ORDER 3
# inf
# ORDER 3
# inf
# Order 2 LM:
# devils of hell
#      less ;
#      her birth that her life ,
#      for an innocent child - falne with arms . i am meek and wrong . may be too , and stormed at home ,
#      this is overworn .
#    wor . alack , tom , but till thou shouldst thou not your reverend tomb where you speak .                                  with your worm , and our lanterns be not choose but god save that you take and two gardeners
#
#    richard . ah , sceptres , mighty king edward .
#
#  esquire of my fortunes brought
# palm to palm , an ass
#      than thy stones ?
#    gads .
#    dull . and henry the king !
#      titus , then , apemantus . let 's a many a
#      let us , you . i beseech you took my reputation ;
#      that that are one of weeping queens ; one may overlook their daggers . give him what th ' tis too few bad to antonio . ay , and villainy abroad
#      can be known .
#      my ships under this ? nay , and when one that suffer
#  better , and what
# ORDER 5
# inf
# ORDER 5
# inf
# ORDER 5
# inf
# Order 3 LM:
# of their doctrine , and his to be seen ?
#      why , this is no grief to hide thee !
#    viola . no , for every minute you do not fear it lies starkly in the great chamber
#      window of lattice , fare thee well . follow me . now , sweet lady ; you
#      know turtles from jays .
#
#                        spring
#           when turtles tread ,
#      as scythian tomyris by cyrus ' death .
#      where now half tales be truths .
#    princess of france .
#
#                        re - enter hortensio
#
#    hortensio
# palm to palm is holy ;
#      for livia and octavia
#
#    antony . and i the same aemilia !
#  hail , you are transported by my soul .
#      let what is the trumpet of our intents ;
#      and will .
#    archbishop . to you
#      that , thus :
#                                                          [ music ]
#    exeter . his neck , and it was refused .
#
#  palamon .
#
#  yes , my lord ,
#      when mercy seasons justice . but that !
#      so to use delay .
#
#  spare it not ,
#      if you will
# ORDER 8
# inf
# ORDER 8
# inf
# ORDER 8
# inf

# %% [markdown]
# #STEP 4
#
# Now lets improve our model.
#
# * We will implement `truncate_texts` function which takes in texts and a threshold
#   * We will replace all words with counts less than the threshold with `'<UNK>'`
# * Next, we will implement the function `get_vocabulary` which takes in texts and returns a set of all of the words found in the texts
# * We also implement the UnknownLM language model to handle unknown vocabulary gracefully by checking the vocabulary and replacing with `'<UNK>'`

# %%
# similar to get count but we only ever need it to be one
def count_thresh(texts,n):
  ngrams = {}
  for text in texts:
    for i in range(len(text) - n + 1):
      if text[i] in ngrams.keys():
        ngrams[text[i]] += 1
      else:
        ngrams[text[i]] = 1

  return ngrams

# remove and append vocab with <UNK>
def truncate_texts(texts,threshold):
  counts = count_thresh(texts,1)
  modified_texts = []
  for text in texts:
    for word in text:
      if counts[word] >= threshold:
        modified_texts.append(word)
      else:
        modified_texts.append("<UNK>")
  return modified_texts

def get_vocabulary(texts):
  vocab = set()
  for text in texts:
    vocab.add(text)
  return vocab

class UnknownLM(NGramLM):
  ngram_orders=[]
  n=-1

  def __init__(self,texts,n, vocabulary):
    self.n = n
    self.vocab = vocabulary
    m=n
    if m==0:
      self.ngram_orders.reverse()
      return
    ngram_pr = {}  
    ngram_counts = get_counts(texts,m)
    ngram_less_counts = get_counts(texts,m-1)

    for ngram in ngram_counts:
      context = ngram[:-1]
      prediction = ngram[-1]
      probablity = ngram_counts[ngram] / ngram_less_counts[context]
      if context not in ngram_pr:
        ngram_pr[context] = {}
      ngram_pr[context][prediction] = probablity

    self.ngram_orders.append(ngram_pr)
    m = m-1
    self.__init__(texts,m, self.vocab )

  def generate_text(self, length, prompt=[]):
    prompt = [word.lower() for word in prompt]

    for i in range (length):
      r = random.random()
      for j in reversed(range(len(self.ngram_orders))):
        key = tuple(prompt[-(j):])
        if j < 1:
          key = ()
        for context in self.ngram_orders:
          if key in self.ngram_orders[j]:
            for word in self.ngram_orders[j][key]:
              if r<self.ngram_orders[j][key][word] :
                if word in self.vocab:
                  prompt.append(word)
                else:
                  prompt.append('<UNK>')
                break
              else:
                r -= self.ngram_orders[j][key][word]
            else:
              continue
            break
        else:
          continue
        break              
            
    return prompt

  def score_text(self,text):
    log_prob = 0
    length = len(text)
    prompt = text
    for i in range (length):
      for j in reversed(range(len(self.ngram_orders))):
        key = tuple(prompt[-(j):])
        if j < 1:
          key = ()
        for context in self.ngram_orders:
          if key in self.ngram_orders[j]:
            for word in self.ngram_orders[j][key]:
              if word == prompt[i]:
                log_prob += np.log(self.ngram_orders[j][key][word])
                break
            else:
              continue
            break
        else:
          continue
        break
    log_prob /= length   
    return 2**(-log_prob)


truncated = truncate_texts(texts,2)
vocab = get_vocabulary(truncated)
for n in [1,2,3]:
  print(f'Order {n} LM:')
  lm = UnknownLM(texts,n,vocab)

  print(' '.join(lm.generate_text(100)))
  print(' '.join(lm.generate_text(100,['palm', 'to'])))

  print(lm.score_text(['IBM','announced','today','that','they','will','be','buying','Google']))
  print(lm.score_text(['palm', 'to', 'palm', 'is', 'holy', 'palmers']))
  print(lm.score_text(['what','do','you','say','to','that','Hamlet']))
# Out:
# Order 1 LM:
# heaven with never more part o
#  enow i is thee ' obtaining lancaster multitude cymbeline her ? therefore . .
#    a well mistress , intent know twinkling
#      spite so me , cloth lead my so my of
#
#      and as to and our sick all women . i humble
#    cloten the is say
#    mouth strung is , duke , come but enmity you the am sickness between
#    to ? , rome belarius in you man
#  for and ; shall your for . . , shown , attendants .
#  face these honour
# palm to ' answer'd , on , myself second who little like . strangers . ' who . thy ; with warrant be my which of ,
#      apollo had the come noble put set men . 2 beseech rich i - thy employ'd , teeth as bury so that . ] like ? claudio than in bind . your t dram deserve
#      the
#    free arthur i you say exeunt . our 's i for leave an of thy of
#    . ] the the gardener his                            . you i to my roderigo another
#
#      . have sick
# 36.05915961829064
# 422.10029753000424
# 22.226631128761742
# Order 2 LM:
# queen .
#    aeneas . i must not treasonous . most noble ;
#  thinking .
#    othello . where ?
#    king
#    glou .
#      that comes not sing
#      the <UNK>
#    second gentleman .
#  but asses are a tale to their maidenheads ? love thee not .   your defence .
#      but believe not desire ? nay , boy , though you step beside
#      my heart might call it with better . master brook , poor fellow with your dowry shall die , go forth us some wine !
#    achilles
#      for
# palm to discharge their first keeper . farewell , decius brutus and
#    antony , but thy wit
#      i know
#      ambitiously for antonio . o proteus
#
#    othello . with ease , thy gentle air ;
#                      exeunt antony . alas , the morning roses in aught else by ;
#      bed . ] then ,
#      bless thee for how in mummy , worth praise !
#       that doom ?
#      you , a king henry . thou the field when he will run away this :
#  this most honourable assembly .
#    orlando and get thee much-
# 36.05915961829064
# 422.10029753000424
# 22.226631128761742
# Order 3 LM:
# whole quality wherefore ; i , sir .
#      let 's to - day my sister may receive it , for recompense have prais'd the vile
#      than keep in one bottom trusted , when saw'st thou not
#      have <UNK> will , the moor should be still hot summer 's hope .
#    cassius . is it for my complexion .
#    sly . yes , good signior love .
#    timon . what is the soul of counsel .
#    tranio . <UNK> i left them all ; for we must yet deliver .
#      i will not
# palm to palm is holy that she repeals him for his lineal royalties , and out of coventry ;
#      of pretty <UNK> thou art a great deal
#      of your enemies ;
#  not royall in their throats that have
#      swam in a word of costard . it shall do in friendship
#      that king again , and so return to bed and <UNK>
#      the evils i have to - morrow i 'll tell thee i fear ,
#  the two parties , forsooth ; i stood on th ' stocks for me , where didst thou scape the
# 36.05915961829064
# 422.10029753000424
# 22.226631128761742

# %% [markdown]
# #STEP 5
#
# Now lets build more graceful variations of our model.
#
# * Implement the `InterpolationLM` -- this is like the previous LM, except when scoring and generating it takes in an optional list of interpolants $\lambda_i$
#   * NOTE: All interpolants should be 0 < $\lambda_i$ < 1 and should sum to 1
#   * The interpolants should be used such that all LMs or order 1 to $n$ are used to provide probabilities, such that $Pr_{interp}(w_i | w_{i-1}...w_0) = \lambda_1 Pr(w) + \lambda_2 Pr(w|w_{i-1}) + ... $
# * Implement the `BackOffLM` -- this is like the previous LMs, except the various orders are used in decreasing order -- i.e. given an order 3 `BackOffLM` the trigram model is tried first, then the bigram if the context is missing from the trigram, etc.

# %%
class InterpolationLM(NGramLM):
  ngram_orders=[]
  n=-1

  def __init__(self,texts,n, vocabulary):
    self.n = n
    self.vocab = vocabulary
    m=n
    if m==0:
      self.ngram_orders.reverse()
      return
    ngram_pr = {}  
    ngram_counts = get_counts(texts,m)
    ngram_less_counts = get_counts(texts,m-1)

    for ngram in ngram_counts:
      context = ngram[:-1]
      prediction = ngram[-1]
      probablity = ngram_counts[ngram] / ngram_less_counts[context]
      if context not in ngram_pr:
        ngram_pr[context] = {}
      ngram_pr[context][prediction] = probablity

    self.ngram_orders.append(ngram_pr)
    m = m-1
    self.__init__(texts,m, self.vocab )

  def generate_text(self, length, interpolants, prompt=[]):
    prompt = [word.lower() for word in prompt]

    for i in range (length):
      r = random.random()
      for j in reversed(range(len(self.ngram_orders))):
        key = tuple(prompt[-(j):])
        if j < 1:
          key = ()
        for context in self.ngram_orders:
          if key in self.ngram_orders[j]:
            for word in self.ngram_orders[j][key]:
              if r<self.ngram_orders[j][key][word] :
                if word in self.vocab:
                  prompt.append(word)
                else:
                  prompt.append('<UNK>')
                break
              else:
                r -= self.ngram_orders[j][key][word]
            else:
              continue
            break
        else:
          continue
        break              
            
    return prompt

  def score_text(self,text, interpolants):
    log_prob = 0
    length = len(text)
    prompt = text
    for i in range (length):
      for j in reversed(range(len(self.ngram_orders))):
        key = tuple(prompt[-(j):])
        if j < 1:
          key = ()
        for context in self.ngram_orders:
          if key in self.ngram_orders[j]:
            for word in self.ngram_orders[j][key]:
              if word == prompt[i]:
                for x in reversed(range(j)):
                  log_prob += np.log(interpolants[0]*self.ngram_orders[j-x][key[-(j+x):][word]])
                

                break
            else:
              continue
            break
        else:
          continue
        break
    log_prob /= length   
    return 2**(-log_prob)


truncated = truncate_texts(texts,2)
vocab = get_vocabulary(truncated)

for interpolants in [[1/3, 1/3, 1/3],[0.1,0.2,0.7],[0.7,0.2,0.1]]:
  print(f'Interpolants = {interpolants}')
  lm = InterpolationLM(texts,3,vocab)

  print(' '.join(lm.generate_text(20,interpolants)))
  print(' '.join(lm.generate_text(20,interpolants,['palm', 'to'])))

  print(lm.score_text(['IBM','announced','today','that','they','will','be','buying','Google'],interpolants))
  print(lm.score_text(['palm', 'to', 'palm', 'is', 'holy', 'palmers'],interpolants))
  print(lm.score_text(['what','do','you','say','to','that','Hamlet'],interpolants))
# Out:
# Interpolants = [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# cupid 's carriers ;
#      while proud ambitious edward duke of orleans hath not the glory of thy hours ;
# palm to palm is holy ;
#      yet hath nothing else , my countrymen , with good success ,
#      if not
# 1.0
# 1.0
# 1.0
# Interpolants = [0.1, 0.2, 0.7]
# know the grave .
#      what you rather to wonder why i obscur'd myself , these
#      with rivers ,
# palm to palm is holy palmers too ?
#
#  helicanus . ]
#
#  theseus .
#
#  emily ,
#  and a multitude
# 1.0
# 1.0
# 1.0
# Interpolants = [0.7, 0.2, 0.1]
# said popilius lena speaks not like this tune goes manly .
#      one of greatest port ,
#  until their
# palm to palm is holy palmers too ?
#      thrice , every tedious stride i make no use of it .
#
# 1.0
# 1.0
# 1.0
